# %% [markdown]
# # Model Comparison

# %% [markdown]
# Connect the variables below to the existing ML4QS notebook/code before execution. Do not enter invented results.

# %%
# Example structure
# Replace X_test, y_test and fitted models with the variables used in the existing project.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Example:
# models = {"LogisticRegression": model_lr, "RandomForest": model_rf}
# for name, model in models.items():
#     pred = model.predict(X_test)
#     print(name, accuracy_score(y_test, pred), f1_score(y_test, pred, average="macro"))
