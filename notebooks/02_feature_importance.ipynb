# %% [markdown]
# # Feature Importance

# %% [markdown]
# Connect the variables below to the existing ML4QS notebook/code before execution. Do not enter invented results.

# %%
# Connect to the final fitted model.
# For tree models:
# importance = model.feature_importances_
# For linear models:
# coefficients = model.coef_
#
# Then create results/feature_importance.csv.
